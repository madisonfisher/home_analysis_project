# %%
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /Users/Madison/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /Users/Madison/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /Users/Madison/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /Users/Madison/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.17.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /Users/Madison/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /Users/Madison/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.5.0)

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('base_inventory_files/city_mean_pending_weekly_smooth_base.csv', header=None).T.to_csv('transposed_inventory_files/city_mean_pending_weekly_smooth.csv', header=False, index=False)
pd.read_csv('base_inventory_files/city_median_pending_weekly_smooth_base.csv', header=None).T.to_csv('transposed_inventory_files/city_median_pending_weekly_smooth.csv', header=False, index=False)
pd.read_csv('base_inventory_files/city_new_pending_weekly_smooth_base.csv', header=None).T.to_csv('transposed_inventory_files/city_new_pending_weekly_smooth.csv', header=False, index=False)
pd.read_csv('base_inventory_files/city_inventory_weekly_allHomes_smooth_base.csv', header=None).T.to_csv('transposed_inventory_files/city_inventory_weekly_allHomes_smooth.csv', header=False, index=False)
pd.read_csv('base_inventory_files/city_inventory_weekly_SFH_smooth_base.csv', header=None).T.to_csv('transposed_inventory_files/city_inventory_weekly_SFH_smooth.csv', header=False, index=False)

# %%
mean_pending = pd.read_csv("transposed_inventory_files/city_mean_pending_weekly_smooth.csv")
median_pending = pd.read_csv("transposed_inventory_files/city_median_pending_weekly_smooth.csv")
new_pending = pd.read_csv("transposed_inventory_files/city_new_pending_weekly_smooth.csv")
inventory_all = pd.read_csv("transposed_inventory_files/city_inventory_weekly_allHomes_smooth.csv")
inventory_SFH = pd.read_csv("transposed_inventory_files/city_inventory_weekly_SFH_smooth.csv")

# %%
mean_pending.columns = mean_pending.iloc[1]
mean_pending = mean_pending.drop([0,1,2,3])
mean_pending = mean_pending.rename(columns={"RegionName": "Date"})
mean_pending = mean_pending.reset_index(drop=True)
mean_pending.insert(1, 'Total_Days', "")
x = 0
for index, row in mean_pending.iterrows():
    mean_pending["Total_Days"][index] = x
    x = x + 7
mean_pending
# Out:
# 1          Date Total_Days United States New York, NY  \
# 0    2018-01-06          0          78.0        103.0
# 1    2018-01-13          7          79.0        106.0
# 2    2018-01-20         14          79.0        106.0
# 3    2018-01-27         21          78.0        107.0
# 4    2018-02-03         28          75.0        104.0
# ..          ...        ...           ...          ...
# 177  2021-05-29       1239           NaN          NaN
# 178  2021-06-05       1246           NaN          NaN
# 179  2021-06-12       1253           NaN          NaN
# 180  2021-06-19       1260           NaN          NaN
# 181  2021-06-26       1267           NaN          NaN
#
# 1   Los Angeles-Long Beach-Anaheim, CA Chicago, IL Dallas-Fort Worth, TX  \
# 0                                 50.0        89.0                  64.0
# 1                                 52.0        89.0                  64.0
# 2                                 52.0        87.0                  64.0
# 3                                 50.0        87.0                  64.0
# 4                                 46.0        83.0                  62.0
# ..                                 ...         ...                   ...
# 177                                NaN         NaN                   NaN
# 178                                NaN         NaN                   NaN
# 179                                NaN         NaN                   NaN
# 180                                NaN         NaN                   NaN
# 181                                NaN         NaN                   NaN
#
# 1   Philadelphia, PA Houston, TX Washington, DC  ... Madison, WI Lakeland, FL  \
# 0               86.0        75.0           71.0  ...        85.0         53.0
# 1               89.0        75.0           74.0  ...        82.0         61.0
# 2               92.0        77.0           74.0  ...        78.0         60.0
# 3               91.0        76.0           72.0  ...        83.0         70.0
# 4               87.0        73.0           73.0  ...        77.0         70.0
# ..               ...         ...            ...  ...         ...          ...
# 177             17.0        18.0            NaN  ...         NaN         10.0
# 178             17.0        17.0            NaN  ...         NaN          9.0
# 179             17.0        17.0            NaN  ...         NaN          9.0
# 180             17.0        17.0            NaN  ...         NaN         10.0
# 181             14.0        17.0            NaN  ...         NaN         10.0
#
# 1   Ogden, UT Daytona Beach, FL Des Moines, IA Jackson, MS Augusta, GA  \
# 0        43.0              58.0           67.0        96.0         NaN
# 1        48.0              65.0           68.0        90.0         NaN
# 2        50.0              58.0           66.0        93.0         NaN
# 3        53.0              65.0           71.0        97.0         NaN
# 4        49.0              73.0           68.0        91.0         NaN
# ..        ...               ...            ...         ...         ...
# 177       NaN              19.0           10.0         NaN        14.0
# 178       NaN              18.0           11.0         NaN        13.0
# 179       NaN              18.0           12.0         NaN        13.0
# 180       NaN              19.0           12.0         NaN        12.0
# 181       NaN              18.0           12.0         NaN        13.0
#
# 1   Harrisburg, PA Provo, UT Fort Collins, CO
# 0             79.0      59.0             61.0
# 1             84.0      56.0             69.0
# 2             82.0      50.0             70.0
# 3             83.0      47.0             74.0
# 4             80.0      42.0             71.0
# ..             ...       ...              ...
# 177           11.0       NaN             41.0
# 178           11.0       NaN             32.0
# 179           11.0       NaN             32.0
# 180           12.0       NaN             28.0
# 181           10.0       NaN             30.0
#
# [182 rows x 98 columns]

# %%
median_pending.columns = median_pending.iloc[1]
median_pending = median_pending.drop([0,1,2,3])
median_pending = median_pending.rename(columns={"RegionName": "Date"})
median_pending = median_pending.reset_index(drop=True)
median_pending.insert(1, 'Total_Days', "")
x = 0
for index, row in median_pending.iterrows():
    median_pending["Total_Days"][index] = x
    x = x + 7
median_pending.columns
# Out:
# Index(['Date', 'Total_Days', 'United States', 'New York, NY',
#        'Los Angeles-Long Beach-Anaheim, CA', 'Chicago, IL',
#        'Dallas-Fort Worth, TX', 'Philadelphia, PA', 'Houston, TX',
#        'Washington, DC', 'Miami-Fort Lauderdale, FL', 'Atlanta, GA',
#        'Boston, MA', 'San Francisco, CA', 'Detroit, MI', 'Riverside, CA',
#        'Phoenix, AZ', 'Seattle, WA', 'Minneapolis-St Paul, MN',
#        'San Diego, CA', 'St. Louis, MO', 'Tampa, FL', 'Baltimore, MD',
#        'Denver, CO', 'Pittsburgh, PA', 'Portland, OR', 'Charlotte, NC',
#        'Sacramento, CA', 'San Antonio, TX', 'Orlando, FL', 'Cincinnati, OH',
#        'Cleveland, OH', 'Kansas City, MO', 'Las Vegas, NV', 'Columbus, OH',
#        'Indianapolis, IN', 'San Jose, CA', 'Austin, TX', 'Virginia Beach, VA',
#        'Nashville, TN', 'Providence, RI', 'Milwaukee, WI', 'Jacksonville, FL',
#        'Memphis, TN', 'Oklahoma City, OK', 'Louisville-Jefferson County, KY',
#        'Hartford, CT', 'Richmond, VA', 'New Orleans, LA', 'Buffalo, NY',
#        'Raleigh, NC', 'Birmingham, AL', 'Salt Lake City, UT', 'Rochester, NY',
#        'Grand Rapids, MI', 'Tucson, AZ', 'Tulsa, OK', 'Fresno, CA',
#        'Worcester, MA', 'Stamford, CT', 'Albuquerque, NM', 'Albany, NY',
#        'Omaha, NE', 'New Haven, CT', 'Bakersfield, CA', 'Knoxville, TN',
#        'Greenville, SC', 'Ventura, CA', 'Allentown, PA', 'El Paso, TX',
#        'Baton Rouge, LA', 'Dayton, OH', 'McAllen, TX', 'Columbia, SC',
#        'Greensboro, NC', 'Akron, OH', 'North Port-Sarasota-Bradenton, FL',
#        'Little Rock, AR', 'Stockton, CA', 'Charleston, SC', 'Syracuse, NY',
#        'Colorado Springs, CO', 'Winston-Salem, NC', 'Wichita, KS',
#        'Springfield, MA', 'Fort Myers, FL', 'Boise City, ID', 'Toledo, OH',
#        'Madison, WI', 'Lakeland, FL', 'Ogden, UT', 'Daytona Beach, FL',
#        'Des Moines, IA', 'Jackson, MS', 'Augusta, GA', 'Harrisburg, PA',
#        'Provo, UT', 'Fort Collins, CO'],
#       dtype='object', name=1)

# %%
new_pending.columns = new_pending.iloc[1]
new_pending = new_pending.drop([0,1,2,3])
new_pending = new_pending.rename(columns={"RegionName": "Date"})
new_pending = new_pending.reset_index(drop=True)
new_pending
# Out:
# 1          Date Los Angeles-Long Beach-Anaheim, CA Chicago, IL  \
# 0    2018-01-06                             2045.0      2266.0
# 1    2018-01-13                             2081.0      2338.0
# 2    2018-01-20                             2041.0      2521.0
# 3    2018-01-27                             2440.0      2928.0
# 4    2018-02-03                             2904.0      3392.0
# ..          ...                                ...         ...
# 177  2021-05-29                                NaN         NaN
# 178  2021-06-05                                NaN         NaN
# 179  2021-06-12                                NaN         NaN
# 180  2021-06-19                                NaN         NaN
# 181  2021-06-26                                NaN         NaN
#
# 1   Dallas-Fort Worth, TX Houston, TX Miami-Fort Lauderdale, FL Atlanta, GA  \
# 0                  1489.0      1373.0                    1358.0      1950.0
# 1                  1444.0      1430.0                    1440.0      2071.0
# 2                  1388.0      1464.0                    1492.0      2207.0
# 3                  1528.0      1708.0                    1723.0      2541.0
# 4                  1725.0      1941.0                    1919.0      2859.0
# ..                    ...         ...                       ...         ...
# 177                2299.0      2459.0                       NaN         NaN
# 178                2238.0      2403.0                       NaN         NaN
# 179                2213.0      2435.0                       NaN         NaN
# 180                2215.0      2429.0                       NaN         NaN
# 181                2245.0      2440.0                       NaN         NaN
#
# 1   Boston, MA Riverside, CA Phoenix, AZ  ... Dayton, OH Greensboro, NC  \
# 0        998.0         868.0         NaN  ...       84.0            NaN
# 1        980.0         883.0         NaN  ...      100.0            NaN
# 2        996.0         900.0         NaN  ...      105.0            NaN
# 3       1212.0        1055.0         NaN  ...      119.0            NaN
# 4       1426.0        1191.0         NaN  ...      133.0            NaN
# ..         ...           ...         ...  ...        ...            ...
# 177        NaN        1255.0      1510.0  ...      268.0           71.0
# 178        NaN        1232.0      1457.0  ...      251.0           69.0
# 179        NaN        1274.0      1449.0  ...      258.0           69.0
# 180        NaN        1275.0      1447.0  ...      269.0           63.0
# 181        NaN        1258.0      1437.0  ...      274.0           59.0
#
# 1   Akron, OH Stockton, CA Charleston, SC Colorado Springs, CO  \
# 0       118.0        174.0          232.0                175.0
# 1       123.0        183.0          240.0                196.0
# 2       128.0        178.0          264.0                202.0
# 3       139.0        198.0          318.0                221.0
# 4       148.0        214.0          376.0                231.0
# ..        ...          ...            ...                  ...
# 177     241.0          NaN            NaN                  NaN
# 178     241.0          NaN            NaN                  NaN
# 179     245.0          NaN            NaN                  NaN
# 180     245.0          NaN            NaN                  NaN
# 181     249.0          NaN            NaN                  NaN
#
# 1   Springfield, MA Toledo, OH Harrisburg, PA Fort Collins, CO
# 0              74.0      116.0          175.0              NaN
# 1              78.0      122.0          172.0              NaN
# 2              76.0      125.0          155.0              NaN
# 3              85.0      141.0          189.0              NaN
# 4             101.0      156.0          222.0              NaN
# ..              ...        ...            ...              ...
# 177             NaN      190.0            NaN             71.0
# 178             NaN      186.0            NaN             68.0
# 179             NaN      188.0            NaN             69.0
# 180             NaN      191.0            NaN             67.0
# 181             NaN      190.0            NaN             65.0
#
# [182 rows x 46 columns]

# %%
inventory_all.columns = inventory_all.iloc[1]
inventory_all = inventory_all.drop([0,1,2,3])
inventory_all = inventory_all.rename(columns={"RegionName": "Date"})
inventory_all = inventory_all.reset_index(drop=True)
inventory_all
# Out:
# 1          Date United States New York, NY Los Angeles-Long Beach-Anaheim, CA  \
# 0    2017-11-04     1297949.0      67386.0                            19426.0
# 1    2017-11-11     1287338.0      66589.0                            19041.0
# 2    2017-11-18     1274429.0      65633.0                            18645.0
# 3    2017-11-25     1256270.0      64374.0                            18129.0
# 4    2017-12-02     1237609.0      63183.0                            17652.0
# ..          ...           ...          ...                                ...
# 186  2021-05-29      613881.0      46757.0                            12042.0
# 187  2021-06-05      618410.0      47233.0                            12041.0
# 188  2021-06-12      629611.0      47992.0                            12166.0
# 189  2021-06-19      638470.0      48478.0                            12271.0
# 190  2021-06-26      652110.0      49105.0                            12477.0
#
# 1   Chicago, IL Dallas-Fort Worth, TX Philadelphia, PA Houston, TX  \
# 0       41171.0               26927.0          24981.0     30777.0
# 1       40442.0               26575.0          25310.0     30554.0
# 2       39565.0               26275.0          25324.0     30247.0
# 3       38407.0               25756.0          25117.0     29860.0
# 4       37275.0               25160.0          24612.0     29514.0
# ..          ...                   ...              ...         ...
# 186     23847.0               14123.0          11379.0     16786.0
# 187     24215.0               14136.0          11528.0     16784.0
# 188     24765.0               14277.0          11787.0     16988.0
# 189     25145.0               14364.0          11932.0     17164.0
# 190     25813.0               14579.0          12214.0     17501.0
#
# 1   Washington, DC Miami-Fort Lauderdale, FL  ... Madison, WI Lakeland, FL  \
# 0          19866.0                   41883.0  ...      2725.0       3086.0
# 1          20371.0                   42186.0  ...      2658.0       3053.0
# 2          20936.0                   42477.0  ...      2573.0       3035.0
# 3          21635.0                   42615.0  ...      2477.0       3017.0
# 4          22260.0                   42823.0  ...      2380.0       3011.0
# ..             ...                       ...  ...         ...          ...
# 186        10735.0                   25401.0  ...      1760.0       1339.0
# 187        10893.0                   25129.0  ...      1786.0       1329.0
# 188        11175.0                   25080.0  ...      1827.0       1360.0
# 189        11319.0                   24761.0  ...      1845.0       1355.0
# 190        11666.0                   24522.0  ...      1874.0       1348.0
#
# 1   Ogden, UT Daytona Beach, FL Des Moines, IA Jackson, MS Augusta, GA  \
# 0      1509.0            4621.0         3570.0      2460.0      3398.0
# 1      1486.0            4660.0         3524.0      2448.0      3380.0
# 2      1470.0            4694.0         3475.0      2429.0      3341.0
# 3      1443.0            4731.0         3409.0      2410.0      3289.0
# 4      1417.0            4752.0         3358.0      2386.0      3238.0
# ..        ...               ...            ...         ...         ...
# 186     778.0            2371.0         2021.0       829.0      1224.0
# 187     784.0            2370.0         1983.0       826.0      1226.0
# 188     799.0            2388.0         1982.0       844.0      1239.0
# 189     815.0            2411.0         2002.0       858.0      1258.0
# 190     841.0            2448.0         2054.0       879.0      1282.0
#
# 1   Harrisburg, PA Provo, UT Fort Collins, CO
# 0           2588.0    1378.0           3065.0
# 1           2634.0    1357.0           2978.0
# 2           2587.0    1335.0           2877.0
# 3           2577.0    1305.0           2756.0
# 4           2538.0    1278.0           2638.0
# ..             ...       ...              ...
# 186          770.0     926.0           1579.0
# 187          791.0     936.0           1564.0
# 188          822.0     967.0           1575.0
# 189          849.0     999.0           1589.0
# 190          882.0    1053.0           1623.0
#
# [191 rows x 97 columns]

# %%
inventory_SFH.columns = inventory_SFH.iloc[1]
inventory_SFH = inventory_SFH.drop([0,1,2,3])
inventory_SFH = inventory_SFH.rename(columns={"RegionName": "Date"})
inventory_SFH = inventory_SFH.reset_index(drop=True)
inventory_SFH
# Out:
# 1          Date United States New York, NY Los Angeles-Long Beach-Anaheim, CA  \
# 0    2017-11-04     1161023.0      51047.0                            16248.0
# 1    2017-11-11     1150663.0      50385.0                            15920.0
# 2    2017-11-18     1138247.0      49595.0                            15602.0
# 3    2017-11-25     1121166.0      48581.0                            15189.0
# 4    2017-12-02     1103702.0      47601.0                            14798.0
# ..          ...           ...          ...                                ...
# 186  2021-05-29      524230.0      27931.0                            10007.0
# 187  2021-06-05      529399.0      28373.0                             9998.0
# 188  2021-06-12      540328.0      28998.0                            10116.0
# 189  2021-06-19      549460.0      29462.0                            10214.0
# 190  2021-06-26      562779.0      30063.0                            10396.0
#
# 1   Chicago, IL Dallas-Fort Worth, TX Philadelphia, PA Houston, TX  \
# 0       34671.0               26097.0          23771.0     29564.0
# 1       34026.0               25741.0          24069.0     29341.0
# 2       33275.0               25438.0          24098.0     29047.0
# 3       32292.0               24918.0          23911.0     28669.0
# 4       31305.0               24319.0          23470.0     28334.0
# ..          ...                   ...              ...         ...
# 186     20527.0               13082.0          10910.0     15413.0
# 187     20918.0               13103.0          11053.0     15437.0
# 188     21410.0               13246.0          11305.0     15653.0
# 189     21799.0               13335.0          11440.0     15850.0
# 190     22331.0               13554.0          11698.0     16192.0
#
# 1   Washington, DC Miami-Fort Lauderdale, FL  ... Madison, WI Lakeland, FL  \
# 0          18232.0                   18940.0  ...      2322.0       3109.0
# 1          18705.0                   19053.0  ...      2263.0       3073.0
# 2          19221.0                   19149.0  ...      2183.0       3052.0
# 3          19865.0                   19156.0  ...      2092.0       3031.0
# 4          20452.0                   19195.0  ...      2000.0       3025.0
# ..             ...                       ...  ...         ...          ...
# 186        10151.0                    9625.0  ...      1440.0       1285.0
# 187        10280.0                    9673.0  ...      1460.0       1276.0
# 188        10515.0                    9792.0  ...      1494.0       1310.0
# 189        10614.0                    9837.0  ...      1515.0       1309.0
# 190        10867.0                    9910.0  ...      1546.0       1306.0
#
# 1   Ogden, UT Daytona Beach, FL Des Moines, IA Jackson, MS Augusta, GA  \
# 0      1474.0            3522.0         3057.0      2430.0      3473.0
# 1      1450.0            3549.0         3010.0      2417.0      3453.0
# 2      1433.0            3571.0         2956.0      2398.0      3412.0
# 3      1406.0            3602.0         2892.0      2380.0      3359.0
# 4      1380.0            3622.0         2840.0      2356.0      3306.0
# ..        ...               ...            ...         ...         ...
# 186     755.0            1878.0         1690.0       817.0      1213.0
# 187     759.0            1879.0         1667.0       812.0      1215.0
# 188     770.0            1904.0         1680.0       829.0      1228.0
# 189     785.0            1938.0         1714.0       842.0      1247.0
# 190     810.0            1976.0         1776.0       862.0      1271.0
#
# 1   Harrisburg, PA Provo, UT Fort Collins, CO
# 0           2444.0    1419.0           2741.0
# 1           2491.0    1394.0           2651.0
# 2           2452.0    1368.0           2547.0
# 3           2449.0    1337.0           2425.0
# 4           2417.0    1309.0           2318.0
# ..             ...       ...              ...
# 186          764.0     813.0           1271.0
# 187          785.0     822.0           1252.0
# 188          817.0     852.0           1251.0
# 189          842.0     886.0           1252.0
# 190          874.0     934.0           1271.0
#
# [191 rows x 97 columns]

# %%
mean_locations = ['United States', 'New York, NY',
       'Los Angeles-Long Beach-Anaheim, CA', 'Chicago, IL',
       'Dallas-Fort Worth, TX', 'Philadelphia, PA', 'Houston, TX',
       'Washington, DC', 'Miami-Fort Lauderdale, FL', 'Atlanta, GA',
       'Boston, MA', 'San Francisco, CA', 'Detroit, MI', 'Riverside, CA',
       'Phoenix, AZ', 'Seattle, WA', 'Minneapolis-St Paul, MN',
       'San Diego, CA', 'St. Louis, MO', 'Tampa, FL', 'Baltimore, MD',
       'Denver, CO', 'Pittsburgh, PA', 'Portland, OR', 'Charlotte, NC',
       'Sacramento, CA', 'San Antonio, TX', 'Orlando, FL', 'Cincinnati, OH',
       'Cleveland, OH', 'Kansas City, MO', 'Las Vegas, NV', 'Columbus, OH',
       'Indianapolis, IN', 'San Jose, CA', 'Austin, TX', 'Virginia Beach, VA',
       'Nashville, TN', 'Providence, RI', 'Milwaukee, WI', 'Jacksonville, FL',
       'Memphis, TN', 'Oklahoma City, OK', 'Louisville-Jefferson County, KY',
       'Hartford, CT', 'Richmond, VA', 'New Orleans, LA', 'Buffalo, NY',
       'Raleigh, NC', 'Birmingham, AL', 'Salt Lake City, UT', 'Rochester, NY',
       'Grand Rapids, MI', 'Tucson, AZ', 'Tulsa, OK', 'Fresno, CA',
       'Worcester, MA', 'Stamford, CT', 'Albuquerque, NM', 'Albany, NY',
       'Omaha, NE', 'New Haven, CT', 'Bakersfield, CA', 'Knoxville, TN',
       'Greenville, SC', 'Ventura, CA', 'Allentown, PA', 'El Paso, TX',
       'Baton Rouge, LA', 'Dayton, OH', 'McAllen, TX', 'Columbia, SC',
       'Greensboro, NC', 'Akron, OH', 'North Port-Sarasota-Bradenton, FL',
       'Little Rock, AR', 'Stockton, CA', 'Charleston, SC', 'Syracuse, NY',
       'Colorado Springs, CO', 'Winston-Salem, NC', 'Wichita, KS',
       'Springfield, MA', 'Fort Myers, FL', 'Boise City, ID', 'Toledo, OH',
       'Madison, WI', 'Lakeland, FL', 'Ogden, UT', 'Daytona Beach, FL',
       'Des Moines, IA', 'Jackson, MS', 'Augusta, GA', 'Harrisburg, PA',
       'Provo, UT', 'Fort Collins, CO']

# %%
#mean locations file
places_count = len(mean_locations)
for j in range(0,places_count):
    mean_location_df = mean_pending.iloc[:, [1,(2+j)]]
    mean_location_df = mean_location_df.rename(columns={f"{mean_locations[j]}": "Mean_Pending"})
    mean_location_df[["Mean_Pending"]] = mean_location_df[["Mean_Pending"]].apply(pd.to_numeric)
    mean_location_df.loc[:,'LastWeek'] = mean_location_df.loc[:,"Mean_Pending"].shift()
    mean_location_df.loc[:,'LastWeek_Diff'] = mean_location_df.loc[:,'LastWeek'].diff()
    mean_location_df.loc[:,'2Weeks'] = mean_location_df.loc[:,"LastWeek"].shift()
    mean_location_df.loc[:,'2Weeks_Diff'] = mean_location_df.loc[:,'2Weeks'].diff()
    mean_location_df = mean_location_df.dropna()
    mean_location_df = mean_location_df.reset_index(drop=True)
    X = mean_location_df[:].drop(['Mean_Pending'], axis = 1)
    y = mean_location_df["Mean_Pending"]
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=57)
    from sklearn.linear_model import LinearRegression
    model = LinearRegression()
    model.fit(X_train, y_train)
    r = len(mean_location_df.index)
    r = r - 1
    #running half a year of predicted data
    for i in range(0,25):
        LastWeekValue = mean_location_df["Mean_Pending"][r]
        TotalDaysValue = mean_location_df["Total_Days"][r] + 7
        LastWeekDifferenceValue = mean_location_df["Mean_Pending"][r] - mean_location_df["LastWeek"][r]
        TwoWeekValue = mean_location_df["LastWeek"][r]
        TwoWeekDifferenceValue = mean_location_df["LastWeek"][r] - mean_location_df["2Weeks"][r]
        NewX = [[TotalDaysValue, LastWeekValue, LastWeekDifferenceValue, TwoWeekValue, TwoWeekDifferenceValue]]
        predicted_value = model.predict(NewX)
        predicted_number = str(predicted_value).lstrip('[').rstrip(']')
        predicted_pending = float(predicted_number)
        new_row = {'Total_Days': TotalDaysValue, 'Mean_Pending': predicted_pending, 'LastWeek': LastWeekValue, 'LastWeek_Diff': LastWeekDifferenceValue, "2Weeks" :TwoWeekValue, "2Weeks_Diff" : TwoWeekDifferenceValue}
        mean_location_df = mean_location_df.append(new_row, ignore_index = True)
        r = r + 1
        i = i + 1
    mean_location_final = mean_location_df[["Total_Days", "Mean_Pending"]]
    mean_location_final = mean_location_final.rename(columns={"Mean_Pending": mean_locations[j]})
    if j == 0:
        final_mean_pending = mean_location_final
    else:
        final_mean_pending = pd.merge(final_mean_pending, mean_location_final, on=["Total_Days", "Total_Days"], how="outer")
    j = j + 1
final_mean_pending = final_mean_pending.fillna('')

# %%
#median locations file
places_count = len(mean_locations)
for j in range(0,places_count):
    median_location_df = median_pending.iloc[:, [1,(2+j)]]
    median_location_df = median_location_df.rename(columns={f"{mean_locations[j]}": "Median_Pending"})
    median_location_df[["Median_Pending"]] = median_location_df[["Median_Pending"]].apply(pd.to_numeric)
    median_location_df.loc[:,'LastWeek'] = median_location_df.loc[:,"Median_Pending"].shift()
    median_location_df.loc[:,'LastWeek_Diff'] = median_location_df.loc[:,'LastWeek'].diff()
    median_location_df.loc[:,'2Weeks'] = median_location_df.loc[:,"LastWeek"].shift()
    median_location_df.loc[:,'2Weeks_Diff'] = median_location_df.loc[:,'2Weeks'].diff()
    median_location_df = median_location_df.dropna()
    median_location_df = median_location_df.reset_index(drop=True)
    X = median_location_df[:].drop(['Median_Pending'], axis = 1)
    y = median_location_df["Median_Pending"]
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=57)
    from sklearn.linear_model import LinearRegression
    model = LinearRegression()
    model.fit(X_train, y_train)
    r = len(median_location_df.index)
    r = r - 1
    #running half a year of predicted data
    for i in range(0,25):
        LastWeekValue = median_location_df["Median_Pending"][r]
        TotalDaysValue = median_location_df["Total_Days"][r] + 7
        LastWeekDifferenceValue = median_location_df["Median_Pending"][r] - median_location_df["LastWeek"][r]
        TwoWeekValue = median_location_df["LastWeek"][r]
        TwoWeekDifferenceValue = median_location_df["LastWeek"][r] - median_location_df["2Weeks"][r]
        NewX = [[TotalDaysValue, LastWeekValue, LastWeekDifferenceValue, TwoWeekValue, TwoWeekDifferenceValue]]
        predicted_value = model.predict(NewX)
        predicted_number = str(predicted_value).lstrip('[').rstrip(']')
        predicted_pending = float(predicted_number)
        new_row = {'Total_Days': TotalDaysValue, 'Median_Pending': predicted_pending, 'LastWeek': LastWeekValue, 'LastWeek_Diff': LastWeekDifferenceValue, "2Weeks" :TwoWeekValue, "2Weeks_Diff" : TwoWeekDifferenceValue}
        median_location_df = median_location_df.append(new_row, ignore_index = True)
        r = r + 1
        i = i + 1
    median_location_final = median_location_df[["Total_Days", "Median_Pending"]]
    median_location_final = median_location_final.rename(columns={"Median_Pending": mean_locations[j]})
    if j == 0:
        final_median_pending = median_location_final
    else:
        final_median_pending = pd.merge(final_median_pending, median_location_final, on=["Total_Days", "Total_Days"], how="outer")
    j = j + 1
final_median_pending = final_median_pending.fillna('')

# %%
final_median_pending
# Out:
# 1    Total_Days United States New York, NY Los Angeles-Long Beach-Anaheim, CA  \
# 0          21.0            41           72                                 23
# 1          28.0            36           70                                 18
# 2          35.0            31           64                                 15
# 3          42.0            26           55                                 14
# 4          49.0            22           45                                 14
# ..          ...           ...          ...                                ...
# 199      1414.0
# 200      1421.0
# 201      1428.0
# 202      1435.0
# 203      1442.0
#
# 1   Chicago, IL Dallas-Fort Worth, TX  Philadelphia, PA  Houston, TX  \
# 0            52                    37         61.000000    38.000000
# 1            43                    33         57.000000    34.000000
# 2            36                    30         51.000000    31.000000
# 3            29                    26         47.000000    27.000000
# 4            21                    23         42.000000    23.000000
# ..          ...                   ...               ...          ...
# 199                                            7.853781    11.579682
# 200                                            7.577571    11.588595
# 201                                            7.315015    11.587992
# 202                                            7.070634    11.578835
# 203                                            6.847088    11.561986
#
# 1   Washington, DC Miami-Fort Lauderdale, FL  ... Madison, WI Lakeland, FL  \
# 0               47                        44  ...          56    28.000000
# 1               45                        44  ...          46    33.000000
# 2               38                        42  ...          39    26.000000
# 3               35                        40  ...          40    27.000000
# 4               33                        37  ...          29    27.000000
# ..             ...                       ...  ...         ...          ...
# 199                                           ...                 4.786297
# 200                                           ...                 4.756006
# 201                                           ...                 4.724248
# 202                                           ...                 4.691064
# 203                                           ...                 4.656491
#
# 1   Ogden, UT Daytona Beach, FL Des Moines, IA Jackson, MS Augusta, GA  \
# 0          29         41.000000      39.000000          50
# 1          20         54.000000      33.000000          48
# 2          14         51.000000      31.000000          44
# 3          12         49.000000      25.000000          45
# 4          11         45.000000      24.000000          37
# ..        ...               ...            ...         ...         ...
# 199                    6.076955      18.303976                -1.67176
# 200                    5.944963      18.201954                -1.95458
# 201                    5.807100      18.078815                -2.23744
# 202                    5.663860      17.941589                -2.52034
# 203                    5.515696      17.796243                -2.80327
#
# 1   Harrisburg, PA Provo, UT  Fort Collins, CO
# 0        51.000000        30                36
# 1        46.000000        26                28
# 2        45.000000        19                18
# 3        50.000000        17                17
# 4        48.000000        16                15
# ..             ...       ...               ...
# 199       5.294594                     17.7252
# 200       5.200781                     17.6855
# 201       5.110814                     17.6564
# 202       5.023485                     17.6352
# 203       4.937754                     17.6198
#
# [204 rows x 97 columns]

# %%
final_mean_pending.to_csv("predicted_inventory_files/city_mean_pending_weekly_predicted.csv", index=False)

# %%
final_median_pending.to_csv("predicted_inventory_files/city_median_pending_weekly_predicted.csv", index=False)

# %%
location_df = pd.read_csv('base_inventory_files/city_mean_pending_weekly_smooth_base.csv')
location_df["LatLong"] = ""
location_df = location_df[["RegionName", "LatLong"]]

# %%
from opencage.geocoder import OpenCageGeocode
key = "1e04c83c5d654b9e9deb683356f0bc66"
geocoder = OpenCageGeocode(key)
for index, row in location_df.iterrows():
    query = location_df["RegionName"][index]  
    results = geocoder.geocode(query)
    Latitude = results[0]["geometry"]["lat"]
    Longitude = results[0]["geometry"]["lng"]
    location_df["LatLong"][index] = [Latitude,Longitude]

# %%
#location_df['LatLong'] = location_df['LatLong'].apply(np.array)
#location_df['LatLong'] = location_df['LatLong'].apply(lambda x: np.array(x))
location_df.dtypes
# Out:
# RegionName    object
# LatLong       object
# dtype: object

# %%
location_df.to_csv("latlong_cities.csv")
location_df.to_json("latlong_cities.json")
